# %%
# !git clone https://github.com/timmyfarrel1/ESRGAN_SKRIPSI.git
# %cd ESRGAN_SKRIPSI

# !python setup.py develop
# !pip install lpips
# Out:
# Cloning into 'ESRGAN_SKRIPSI'...
# remote: Enumerating objects: 590, done.
# remote: Counting objects: 100% (590/590), done.
# remote: Compressing objects: 100% (487/487), done.
# remote: Total 590 (delta 246), reused 348 (delta 83), pack-reused 0 (from 0)
# Receiving objects: 100% (590/590), 1.41 MiB | 6.05 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# /kaggle/working/ESRGAN_SKRIPSI
# /usr/local/lib/python3.11/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# ...

# %% [markdown]
# SETTING TRAIN

# %%
# import yaml
import copy
import yaml
# Path YAML
template_path = '/kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_ESRGAN_x4.yml'

# Skenario kandidat default terbaik
scenarios = {
    'Combo234_Boosted': {
        'name': 'Combo234_Boosted',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv2_2': 0.2,
            'conv3_3': 0.5,
            'conv5_4': 1.0,
        }   
    },
    'Combo345_Boosted': {
        'name': 'Combo345_Boosted',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.2,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.3,
            'conv4_4': 0.7,
            'conv5_4': 1.0,
        } 
    },
    'Mid': {
        'name': 'Mid_test',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.005,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 1.0,
        } 
    },
    'Mid_Boosted': {
        'name': 'Mid_Boosted',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 1.0,
        },
    },
     'Mid_v3': {
        'name': 'Mid_v3',
        'pixel_loss_weight': 10,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.005,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 1.0,
        } 
    },
    'DefaultA_v2': {
        'name': 'DefaultA_v2',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.003,
        'layer_weights': {
            'conv5_4': 1.0,
        } 
    },
    'Default_Perceptual': {
        'name': 'Default_Perceptual',
        'pixel_loss_weight': 0.05,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.1,
            'conv4_4': 0.3,
            'conv5_4': 1.0,
        } 
    },
    'Default_V3': {
        'name': 'Default_V3',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.5,
            'conv4_4': 0.5,
            'conv5_4': 1.0,
        } 
    },
    'Default_V4': {
        'name': 'Default_V4',
        'pixel_loss_weight': 0.03,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.3,
            'conv4_4': 0.7,
            'conv5_4': 1.0,
        }
    },
    'Default_V5': {
        'name': 'Default_V5',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.3,
            'conv4_4': 0.3,
            'conv5_4': 1.0,
        }
    },
    'Default_V7': {
        'name': 'Default_V7',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.25,
            'conv4_4': 0.4,
            'conv5_4': 1.0,
        }
    },
    'Default_V8': {
        'name': 'Default_V8',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 0.5,
        }
    },
    'Default_V10': {
        'name': 'Default_V10',
        'pixel_loss_weight': 30,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.005,
        'layer_weights': {
            'conv3_3': 0.5,
            'conv4_4': 0.5,
            'conv5_4':0.5,
        }
    },
    'Default_V11': {
        'name': 'Default_V11',
        'pixel_loss_weight': 15,
        'perceptual_loss_weight': 0.2,
        'gan_loss_weight': 0.1,
        'layer_weights': {
            'conv3_3': 0.5,
            'conv4_4': 0.5,
            'conv5_4':0.5,
        }
    },
    'Default_V12': {
        'name': 'Default_V12',
        'pixel_loss_weight': 10,
        'perceptual_loss_weight': 0.12,
        'gan_loss_weight': 0.002,
        'layer_weights': {
            'conv3_3': 0.5,
            'conv4_4': 0.5,
            'conv5_4':0.5,
        }
    }
}


# Baca YAML
with open(template_path, 'r') as file:
    base_config = yaml.safe_load(file)

# Loop tiap skenario
for key, scenario in scenarios.items():
    config = copy.deepcopy(base_config)

    # Pengaturan umum
    config['name'] = scenario['name']
    config['num_gpu'] = 1
    config['manual_seed'] = 42

    # Loss weights
    config['train']['pixel_opt']['loss_weight'] = float(scenario['pixel_loss_weight'])
    config['train']['perceptual_opt']['perceptual_weight'] = float(scenario['perceptual_loss_weight'])
    config['train']['gan_opt']['loss_weight'] = float(scenario['gan_loss_weight'])

    #PerceptualLayer
    config['train']['perceptual_opt']['layer_weights'] = scenario['layer_weights']
    # Dataset
    config['datasets']['train']['name'] = 'Train_Potato'
    config['datasets']['train']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/train/train_HR'
    config['datasets']['train']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/train/train_LR'
    config['datasets']['train']['gt_size'] = 128
    config['datasets']['train']['batch_size_per_gpu'] = 8
    config['datasets']['train']['num_worker_per_gpu'] = 4
    config['datasets']['train']['dataset_enlarge_ratio'] = 1

    config['datasets']['val']['name'] = 'Val_Potato'
    config['datasets']['val']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/val/val_HR'
    config['datasets']['val']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/val/val_LR'

    # Pretrained model
    config['path']['pretrain_network_g'] = '/kaggle/input/esrgan_pretrained/pytorch/x4/1/ESRGAN_SRx4_DF2KOST_official-ff704c30.pth'

    # Scheduler dan training iter
    config['train']['scheduler']['milestones'] = [3750, 7500, 11250]
    config['train']['total_iter'] = 15000

    # Validasi
    config['val']['val_freq'] = 750

    # Metrik
    config['train']['metrics'] = {
        'ssim': {'type': 'calculate_ssim', 'crop_border': 4, 'test_y_channel': False, 'better': 'higher'},
        'psnr': {'type': 'calculate_psnr', 'crop_border': 4, 'test_y_channel': False, 'better': 'higher'},
        'lpips': {'type': 'calculate_lpips', 'crop_border': 4, 'test_y_channel': False, 'better': 'lower'}
    }
    config['val']['metrics'] = copy.deepcopy(config['train']['metrics'])

    # Logger
    config['logger']['print_freq'] = 25
    config['logger']['save_checkpoint_freq'] = 3000
    config['logger']['use_tb_logger'] = True

    # Simpan file YAML
    dst_path = f'/kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_{scenario["name"]}.yml'
    with open(dst_path, 'w') as out_file:
        yaml.dump(config, out_file, default_flow_style=False)

    print(f"Konfigurasi {scenario['name']} berhasil dibuat di: {dst_path}")
# Out:
# Konfigurasi Combo234_Boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Combo234_Boosted.yml
# Konfigurasi Combo345_Boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Combo345_Boosted.yml
# Konfigurasi Mid_test berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Mid_test.yml
# Konfigurasi Mid_Boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Mid_Boosted.yml
# Konfigurasi Mid_v3 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Mid_v3.yml
# Konfigurasi DefaultA_v2 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_DefaultA_v2.yml
# Konfigurasi Default_Perceptual berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Default_Perceptual.yml
# Konfigurasi Default_V3 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Default_V3.yml
# ...

# %%
SETTING PRE-TRAINED X2

# %%
# import yaml
import copy
import yaml
# Path YAML
template_path = '/kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_ESRGAN_x4.yml'



# Baca YAML
with open(template_path, 'r') as file:
    base_config = yaml.safe_load(file)

config = copy.deepcopy(base_config)
 # Pengaturan umum
config['num_gpu'] = 1
config['manual_seed'] = 42
config['scale'] = 2

# Dataset
config['datasets']['train']['name'] = 'Train_Potato'
config['datasets']['train']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/train/train_HR'
config['datasets']['train']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/train/train_LR_x2'
config['datasets']['train']['gt_size'] = 128
config['datasets']['train']['batch_size_per_gpu'] = 8
config['datasets']['train']['num_worker_per_gpu'] = 4
config['datasets']['train']['dataset_enlarge_ratio'] = 1

config['datasets']['val']['name'] = 'Val_Potato'
config['datasets']['val']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/val/val_HR'
config['datasets']['val']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/val/val_LR_x2'

# Pretrained model
config['path']['pretrain_network_g'] = '/kaggle/input/esrgan_pretrained/pytorch/x4/1/ESRGAN_SRx4_DF2KOST_official-ff704c30.pth'

# Scheduler dan training iter
config['train']['scheduler']['milestones'] = [3750, 7500, 11250]
config['train']['total_iter'] = 7500

# Validasi
config['val']['val_freq'] = 750

# Metrik
config['train']['metrics'] = {
        'ssim': {'type': 'calculate_ssim', 'crop_border': 4, 'test_y_channel': False, 'better': 'higher'},
        'psnr': {'type': 'calculate_psnr', 'crop_border': 4, 'test_y_channel': False, 'better': 'higher'},
        'lpips': {'type': 'calculate_lpips', 'crop_border': 4, 'test_y_channel': False, 'better': 'lower'}
    }
config['val']['metrics'] = copy.deepcopy(config['train']['metrics'])

# Logger
config['logger']['print_freq'] = 25
config['logger']['save_checkpoint_freq'] = 3750
config['logger']['use_tb_logger'] = True

# Simpan file YAML
dst_path = f'/kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_pretrained_x2.yml'

with open(dst_path, 'w') as out_file:
    yaml.dump(config, out_file, default_flow_style=False)

    print(f"Konfigurasi berhasil dibuat di: {dst_path}")
# Out:
# Konfigurasi berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_pretrained_x2.yml

# %%
# !python basicsr/train.py -opt /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Default_V12.yml
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|█████████████████████████████████████████| 528M/528M [00:02<00:00, 230MB/s]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/vgg.pth
# ...

# %% [markdown]
# SETTING TRAINING X2

# %%
# import yaml
import copy
import yaml
# Path YAML
template_path = '/kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_ESRGAN_x4.yml'

# Skenario kandidat default terbaik
scenarios = {
    'Combo234_Boosted': {
        'name': 'Combo234_Boosted',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv2_2': 0.2,
            'conv3_3': 0.5,
            'conv5_4': 1.0,
        }   
    },
    'Combo345_Boosted': {
        'name': 'Combo345_Boosted',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.2,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.3,
            'conv4_4': 0.7,
            'conv5_4': 1.0,
        } 
    },
    'Mid': {
        'name': 'Mid_test',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.005,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 1.0,
        } 
    },
    'Mid_Boosted': {
        'name': 'Mid_Boosted',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 1.0,
        },
    },
     'Mid_v3': {
        'name': 'Mid_v3',
        'pixel_loss_weight': 10,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.005,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 1.0,
        } 
    },
    'DefaultA_v2': {
        'name': 'DefaultA_v2',
        'pixel_loss_weight': 0.01,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.003,
        'layer_weights': {
            'conv5_4': 1.0,
        } 
    },
    'Default_Perceptual': {
        'name': 'Default_Perceptual',
        'pixel_loss_weight': 0.05,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.1,
            'conv4_4': 0.3,
            'conv5_4': 1.0,
        } 
    },
    'Default_V3': {
        'name': 'Default_V3',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.5,
            'conv4_4': 0.5,
            'conv5_4': 1.0,
        } 
    },
    'Default_V4': {
        'name': 'Default_V4',
        'pixel_loss_weight': 0.03,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.3,
            'conv4_4': 0.7,
            'conv5_4': 1.0,
        }
    },
    'Default_V5': {
        'name': 'Default_V5',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.3,
            'conv4_4': 0.3,
            'conv5_4': 1.0,
        }
    },
    'Default_V7': {
        'name': 'Default_V7',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 0.25,
            'conv4_4': 0.4,
            'conv5_4': 1.0,
        }
    },
    'Default_V8': {
        'name': 'Default_V8',
        'pixel_loss_weight': 0.02,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.001,
        'layer_weights': {
            'conv3_3': 1.0,
            'conv4_4': 0.5,
        }
    },
    'Default_V9': {
        'name': 'Default_V9',
        'pixel_loss_weight': 0.1,
        'perceptual_loss_weight': 1.0,
        'gan_loss_weight': 0.003,
        'layer_weights': {
            'conv3_3': 0.5,
            'conv4_4': 0.5,
            'conv5_4':0.5,
        }
    }
}


# Baca YAML
with open(template_path, 'r') as file:
    base_config = yaml.safe_load(file)

# Loop tiap skenario
for key, scenario in scenarios.items():
    config = copy.deepcopy(base_config)

    # Pengaturan umum
    config['name'] = scenario['name']
    config['num_gpu'] = 1
    config['manual_seed'] = 42
    config['scale'] = 2

    # Loss weights
    config['train']['pixel_opt']['loss_weight'] = float(scenario['pixel_loss_weight'])
    config['train']['perceptual_opt']['perceptual_weight'] = float(scenario['perceptual_loss_weight'])
    config['train']['gan_opt']['loss_weight'] = float(scenario['gan_loss_weight'])

    #PerceptualLayer
    config['train']['perceptual_opt']['layer_weights'] = scenario['layer_weights']
    # Dataset
    config['datasets']['train']['name'] = 'Train_Potato'
    config['datasets']['train']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/train/train_HR'
    config['datasets']['train']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/train/train_LR_x2'
    config['datasets']['train']['gt_size'] = 128
    config['datasets']['train']['batch_size_per_gpu'] = 8
    config['datasets']['train']['num_worker_per_gpu'] = 4
    config['datasets']['train']['dataset_enlarge_ratio'] = 1

    config['datasets']['val']['name'] = 'Val_Potato'
    config['datasets']['val']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/val/val_HR'
    config['datasets']['val']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/val/val_LR_x2'

    # Pretrained model
    config['path']['pretrain_network_g'] = '/kaggle/input/esrgan_pretrained_2x/pytorch/default/1/net_g_latest (2).pth'

    # Scheduler dan training iter
    config['train']['scheduler']['milestones'] = [3750, 7500, 11250]
    config['train']['total_iter'] = 15000

    # Validasi
    config['val']['val_freq'] = 750

    # Metrik
    config['train']['metrics'] = {
        'ssim': {'type': 'calculate_ssim', 'crop_border': 4, 'test_y_channel': False, 'better': 'higher'},
        'psnr': {'type': 'calculate_psnr', 'crop_border': 4, 'test_y_channel': False, 'better': 'higher'},
        'lpips': {'type': 'calculate_lpips', 'crop_border': 4, 'test_y_channel': False, 'better': 'lower'}
    }
    config['val']['metrics'] = copy.deepcopy(config['train']['metrics'])

    # Logger
    config['logger']['print_freq'] = 25
    config['logger']['save_checkpoint_freq'] = 3000
    config['logger']['use_tb_logger'] = True

    # Simpan file YAML
    dst_path = f'/kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_{scenario["name"]}_x2.yml'
    with open(dst_path, 'w') as out_file:
        yaml.dump(config, out_file, default_flow_style=False)

    print(f"Konfigurasi {scenario['name']} berhasil dibuat di: {dst_path}")
# Out:
# Konfigurasi Combo234_Boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Combo234_Boosted_x2.yml
# Konfigurasi Combo345_Boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Combo345_Boosted_x2.yml
# Konfigurasi Mid_test berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Mid_test_x2.yml
# Konfigurasi Mid_Boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Mid_Boosted_x2.yml
# Konfigurasi Mid_v3 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Mid_v3_x2.yml
# Konfigurasi DefaultA_v2 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_DefaultA_v2_x2.yml
# Konfigurasi Default_Perceptual berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Default_Perceptual_x2.yml
# Konfigurasi Default_V3 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Default_V3_x2.yml
# ...

# %%
# !python basicsr/train.py -opt /kaggle/working/ESRGAN_SKRIPSI/options/train/ESRGAN/train_Default_V9_x2.yml
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|█████████████████████████████████████████| 528M/528M [00:02<00:00, 209MB/s]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/vgg.pth
# ...

# %%
# !zip -r tb_logger_DefaultV11.zip /kaggle/working/ESRGAN_SKRIPSI/tb_logger/Default_V11
# Out:
#   adding: kaggle/working/ESRGAN_SKRIPSI/tb_logger/Default_V11/ (stored 0%)
#   adding: kaggle/working/ESRGAN_SKRIPSI/tb_logger/Default_V11/events.out.tfevents.1753709033.b8cbb2a9ff78.1245.0 (deflated 70%)

# %% [markdown]
# SETTING TEST

# %%
import yaml
import copy

# Path YAML
template_path = '/kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_x4.yml'

# Baca YAML
with open(template_path, 'r') as file:
    base_config = yaml.safe_load(file)

scenarios = {
    'Default': {
        'name' : 'ESRGAN_Default',
        'model_path' : '/kaggle/input/esrgan_default/pytorch/default/1/net_g_latest.pth'
    },
    'PixelDominant' : {
        'name' : 'ESRGAN_PixelDominant',
        'model_path' : '/kaggle/input/esrgan_pixeldominant/pytorch/default/1/net_g_latest.pth'    
    },
    'Mid_boosted' : {
        'name' : 'ESRGAN_Mid_boosted',
        'model_path' : '/kaggle/input/esrgan_mid_boosted/pytorch/default/1/net_g_latest.pth'    
    },
    'ESRGAN_Default_Perceptual' : {
        'name' : 'ESRGAN_Default_Perceptual',
        'model_path' : '/kaggle/input/esrgan_default_refined/pytorch/default/1/net_g_latest.pth'    
    },
    'ESRGAN_DefaultV3' : {
        'name' : 'ESRGAN_DefaultV3',
        'model_path' : '/kaggle/input/esrgan_defaultv3/pytorch/default/1/net_g_latest.pth'    
    },
    'ESRGAN_DefaultV7' : {
        'name' : 'ESRGAN_DefaultV7',
        'model_path' : '/kaggle/input/esrgan-defaultv7/pytorch/default/1/net_g_latest.pth'    
    },
    'ESRGAN_DefaultV9' : {
        'name' : 'ESRGAN_DefaultV9',
        'model_path' : '/kaggle/input/esrgan_defaultv9/pytorch/default/1/net_g_latest (2).pth'    
    }
}

for key, scenario in scenarios.items():
    config = copy.deepcopy(base_config)

    # Mengubah nama eksperimen dan pengaturan umum
    config['name'] = scenario['name']

    # Ubah pengaturan dataset
    config['datasets']['test_1']['name'] = 'Test_Potato'
    config['datasets']['test_1']['dataroot_gt'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/test/test_HR'
    config['datasets']['test_1']['dataroot_lq'] = '/kaggle/input/data-latih-sistem-esrgan/data_latih_sistem/test/test_LR'

    # Memanggil model pre-trained
    config['path']['pretrain_network_g'] = scenario['model_path']

    # Simpan file YAML baru
    dst_path = f'/kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_{scenario["name"]}.yml'
    with open(dst_path, 'w') as out_file:
        yaml.dump(config, out_file, default_flow_style=False)

    print(f"Konfigurasi {scenario['name']} berhasil dibuat di: {dst_path}")
# Out:
# Konfigurasi ESRGAN_Default berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_Default.yml
# Konfigurasi ESRGAN_PixelDominant berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_PixelDominant.yml
# Konfigurasi ESRGAN_Mid_boosted berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_Mid_boosted.yml
# Konfigurasi ESRGAN_Default_Perceptual berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_Default_Perceptual.yml
# Konfigurasi ESRGAN_DefaultV3 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_DefaultV3.yml
# Konfigurasi ESRGAN_DefaultV7 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_DefaultV7.yml
# Konfigurasi ESRGAN_DefaultV9 berhasil dibuat di: /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_DefaultV9.yml

# %%
# !python basicsr/test.py -opt /kaggle/working/ESRGAN_SKRIPSI/options/test/ESRGAN/test_ESRGAN_DefaultV9.yml
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|█████████████████████████████████████████| 528M/528M [00:03<00:00, 183MB/s]
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/vgg.pth
# ...

# %%
# !zip -r Test_DefaultV9.zip /kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato
# Out:
#   adding: kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato/ (stored 0%)
#   adding: kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato/potato_early_blight_image_448_ESRGAN_DefaultV9.png (deflated 0%)
#   adding: kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato/potato_healthy_aug_265_ESRGAN_DefaultV9.png (deflated 0%)
#   adding: kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato/potato_healthy_aug_349_ESRGAN_DefaultV9.png (deflated 0%)
#   adding: kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato/potato_healthy_aug_716_ESRGAN_DefaultV9.png (deflated 0%)
#   adding: kaggle/working/ESRGAN_SKRIPSI/results/ESRGAN_DefaultV9/visualization/Test_Potato/potato_early_blight_image_813_ESRGAN_DefaultV9.png (deflated 0%)
# ...
